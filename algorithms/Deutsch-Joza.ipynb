# %% [markdown]
# ## Deutsch-Joza Algorithm
#
# ### Introduction
#
# The Deutsch-Joza algorithm is a foundational quantum algorithm developed by David Deutsch and Richard Joza as an expansion on Deutsch's original algorithm, which only interacted with a two qubit state. Deutsch's original algorithm
